# %% [markdown]
# <a href="https://colab.research.google.com/github/annaklaracss/data_science-/blob/main/Data_Visualization_criando_gr%C3%A1ficos_com_bibliotecas_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as spd

# %%
df = spd.read_csv('/content/canadian_immegration_data.csv')

# %%
df
# Out:
#             Country Continent              Region             DevName  1980  \
# 0       Afghanistan      Asia       Southern Asia  Developing regions    16
# 1           Albania    Europe     Southern Europe   Developed regions     1
# 2           Algeria    Africa     Northern Africa  Developing regions    80
# 3    American Samoa   Oceania           Polynesia  Developing regions     0
# 4           Andorra    Europe     Southern Europe   Developed regions     0
# ..              ...       ...                 ...                 ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  Developing regions  1191
# 191  Western Sahara    Africa     Northern Africa  Developing regions     0
# 192           Yemen      Asia        Western Asia  Developing regions     1
# 193          Zambia    Africa      Eastern Africa  Developing regions    11
# 194        Zimbabwe    Africa      Eastern Africa  Developing regions    72
#
# ...

# %%
df.info() #informações dos dados importados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    195 non-null    object
#  1   Continent  195 non-null    object
#  2   Region     195 non-null    object
#  3   DevName    195 non-null    object
#  4   1980       195 non-null    int64
#  5   1981       195 non-null    int64
#  6   1982       195 non-null    int64
#  7   1983       195 non-null    int64
#  8   1984       195 non-null    int64
#  9   1985       195 non-null    int64
#  10  1986       195 non-null    int64
#  11  1987       195 non-null    int64
#  12  1988       195 non-null    int64
#  13  1989       195 non-null    int64
#  14  1990       195 non-null    int64
#  15  1991       195 non-null    int64
#  16  1992       195 non-null    int64
#  17  1993       195 non-null    int64
#  18  1994       195 non-null    int64
#  19  1995       195 non-null    int64
# ...

# %%
#observamos que não ha nenhum dado nulo. Dessa forma, não precisamos fazer nenhum tratamento de dados nulos.
#Então passaremos a analisar as tendencias de imigração no brasil ao longo dos anos.

# %%
df.set_index('Country', inplace=True)

# %%
#Ela pega a coluna chamada 'Country' (País) do seu DataFrame df e a transforma no índice (rótulo das linhas)
#desse DataFrame. Ao fazer isso, a coluna 'Country' deixa de ser uma coluna de dados comum e passa a ser a referência
#principal para identificar cada linha, facilitando operações de seleção e alinhamento de dados baseadas nos países.
# Como inplace=True, essa alteração é aplicada diretamente ao df original.

# %% [markdown]
#  Country       City  Population
# 0    Brazil  São Paulo   12000000
# 1      USA   New York    8000000
# 2    Brazil  Rio de Janeiro 6000000
# 3      USA    Los Angeles 4000000
#
# Após executar df.set_index('Country', inplace=True), o DataFrame df se parecerá com isto:
#
# City  Population
# Country
# Brazil  São Paulo   12000000
# USA    New York    8000000
# Brazil  Rio de Janeiro 6000000
# USA    Los Angeles 4000000

# %%
anos = list(map(str, range(1980, 2014))) #não considera o ultimo valor. entao ele pegara até 2013.

# %% [markdown]
# **range(1980, 2014):**
#
# A função range() gera uma sequência de números.
# O primeiro argumento (1980) é o início da sequência (inclusive).
# O segundo argumento (2014) é o fim da sequência (exclusivo). Isso significa que a sequência irá até 2013.
# Portanto, range(1980, 2014) gera uma sequência de números inteiros: 1980, 1981, 1982, ..., 2012, 2013.
#
# **map(str, ...):**
#
# Aplica a função str() (que converte para string) a cada número gerado por range().
# Cada número inteiro (1980, 1981, etc.) será convertido em sua representação de string ('1980', '1981', etc.).
#
# **list(...):**
#
# Converte o objeto map resultante em uma lista.

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
brasil = df.loc['Brazil', anos] #para pegar os anos apenas do brasil, com todos os anos

# %%
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brazil, dtype: object

# %%
#agora vamos transformar em um data frame

# %%
brasil_dic= {'ano':brasil.index.tolist(), 'imigrantes': brasil.values.tolist()} #nomenando as colunas listando-as
dados_brasil = spd.DataFrame(brasil_dic)

# %%
#tolist() = usado para criar uma lista

# %%
dados_brasil #data frame formado
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes']) #(x,y)

# %%
#melhorando a visualização do gráfico

# %%
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes']) #(x,y)
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.show() #código para apenas mostrar o grafico . tudo que tiver abaixo do show não será executado.

# %%
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes']) #(x,y)
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.yticks([500, 1000, 1500, 2000, 2500, 3000])
plt.xlabel('Ano')
plt.ylabel('Imigrantes')
plt.title('Imigrantes do Brasil para o canadá')
plt.show()

# %%
plt.figure(figsize=(8,4)) #o primeiro é a largura e o segundo é a altura
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes']) #(x,y)
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.yticks([500, 1000, 1500, 2000, 2500, 3000])
plt.xlabel('Ano')
plt.ylabel('Imigrantes')
plt.title('Imigrantes do Brasil para o canadá')
plt.show()

# %%
fig,ax = plt.subplots(figsize= (8,4) ) #fig permite que uma figura seja criada e ax cria o eixo da fogura
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots(figsize= (8,4) ) #fig permite que uma figura seja criada e ax cria o eixo da fogura
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
ax.set_xticks(['1980','1985','1990','1995','2000','2005','2010'])
ax.set_xlabel('Ano')
ax.set_title('Imigrantes do Brasil para o canadá\n 1980 á 2013')
ax.set_ylabel('Imigrantes')
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #colocando a frequencia de 5 em 5 anos
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# xaxis: Isso acessa as propriedades do eixo X (o eixo horizontal) da sua área de plotagem (ax).
#
# set_major_locator(): Este é um método usado para definir como as principais marcas de seleção (ticks) serão posicionadas no eixo. As "major ticks" são as marcas maiores e mais visíveis que geralmente vêm com um rótulo de valor.
#
# plt.MultipleLocator(5): Aqui, você está criando um objeto MultipleLocator. Ele faz parte do módulo ticker do Matplotlib (muitas vezes acessado diretamente via plt se matplotlib.pyplot foi importado como plt). Ao passar o número 5 para ele, você está dizendo ao Matplotlib para colocar as marcas de seleção principais do eixo X a cada múltiplo de 5. Ou seja, as marcas aparecerão em 0, 5, 10, 15, e assim por diante.
