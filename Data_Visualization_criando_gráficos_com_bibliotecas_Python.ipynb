# %% [markdown]
# <a href="https://colab.research.google.com/github/annaklaracss/data_science-/blob/main/Data_Visualization_criando_gr%C3%A1ficos_com_bibliotecas_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as spd

# %%
df = spd.read_csv('/content/canadian_immegration_data.csv')

# %%
df
# Out:
#             Country Continent              Region             DevName  1980  \
# 0       Afghanistan      Asia       Southern Asia  Developing regions    16
# 1           Albania    Europe     Southern Europe   Developed regions     1
# 2           Algeria    Africa     Northern Africa  Developing regions    80
# 3    American Samoa   Oceania           Polynesia  Developing regions     0
# 4           Andorra    Europe     Southern Europe   Developed regions     0
# ..              ...       ...                 ...                 ...   ...
# 190        Viet Nam      Asia  South-Eastern Asia  Developing regions  1191
# 191  Western Sahara    Africa     Northern Africa  Developing regions     0
# 192           Yemen      Asia        Western Asia  Developing regions     1
# 193          Zambia    Africa      Eastern Africa  Developing regions    11
# 194        Zimbabwe    Africa      Eastern Africa  Developing regions    72
#
# ...

# %%
df.info() #informações dos dados importados
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 39 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    195 non-null    object
#  1   Continent  195 non-null    object
#  2   Region     195 non-null    object
#  3   DevName    195 non-null    object
#  4   1980       195 non-null    int64
#  5   1981       195 non-null    int64
#  6   1982       195 non-null    int64
#  7   1983       195 non-null    int64
#  8   1984       195 non-null    int64
#  9   1985       195 non-null    int64
#  10  1986       195 non-null    int64
#  11  1987       195 non-null    int64
#  12  1988       195 non-null    int64
#  13  1989       195 non-null    int64
#  14  1990       195 non-null    int64
#  15  1991       195 non-null    int64
#  16  1992       195 non-null    int64
#  17  1993       195 non-null    int64
#  18  1994       195 non-null    int64
#  19  1995       195 non-null    int64
# ...

# %%
#observamos que não ha nenhum dado nulo. Dessa forma, não precisamos fazer nenhum tratamento de dados nulos.
#Então passaremos a analisar as tendencias de imigração no brasil ao longo dos anos.

# %%
df.set_index('Country', inplace=True)

# %%
#Ela pega a coluna chamada 'Country' (País) do seu DataFrame df e a transforma no índice (rótulo das linhas)
#desse DataFrame. Ao fazer isso, a coluna 'Country' deixa de ser uma coluna de dados comum e passa a ser a referência
#principal para identificar cada linha, facilitando operações de seleção e alinhamento de dados baseadas nos países.
# Como inplace=True, essa alteração é aplicada diretamente ao df original.

# %% [markdown]
#  Country       City  Population
# 0    Brazil  São Paulo   12000000
# 1      USA   New York    8000000
# 2    Brazil  Rio de Janeiro 6000000
# 3      USA    Los Angeles 4000000
#
# Após executar df.set_index('Country', inplace=True), o DataFrame df se parecerá com isto:
#
# City  Population
# Country
# Brazil  São Paulo   12000000
# USA    New York    8000000
# Brazil  Rio de Janeiro 6000000
# USA    Los Angeles 4000000

# %%
anos = list(map(str, range(1980, 2014))) #não considera o ultimo valor. entao ele pegara até 2013.

# %% [markdown]
# **range(1980, 2014):**
#
# A função range() gera uma sequência de números.
# O primeiro argumento (1980) é o início da sequência (inclusive).
# O segundo argumento (2014) é o fim da sequência (exclusivo). Isso significa que a sequência irá até 2013.
# Portanto, range(1980, 2014) gera uma sequência de números inteiros: 1980, 1981, 1982, ..., 2012, 2013.
#
# **map(str, ...):**
#
# Aplica a função str() (que converte para string) a cada número gerado por range().
# Cada número inteiro (1980, 1981, etc.) será convertido em sua representação de string ('1980', '1981', etc.).
#
# **list(...):**
#
# Converte o objeto map resultante em uma lista.

# %%
anos
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
brasil = df.loc['Brazil', anos] #para pegar os anos apenas do brasil, com todos os anos

# %%
brasil
# Out:
# 1980     211
# 1981     220
# 1982     192
# 1983     139
# 1984     145
# 1985     130
# 1986     205
# 1987     244
# 1988     394
# 1989     650
# 1990     650
# 1991     877
# 1992    1066
# 1993     866
# 1994     566
# 1995     572
# 1996     586
# 1997     591
# 1998     531
# 1999     626
# 2000     845
# 2001     847
# 2002     745
# 2003     839
# 2004     917
# 2005     969
# 2006    1181
# 2007    1746
# 2008    2138
# 2009    2509
# 2010    2598
# 2011    1508
# 2012    1642
# 2013    1714
# Name: Brazil, dtype: object

# %%
#agora vamos transformar em um data frame

# %%
brasil_dic= {'ano':brasil.index.tolist(), 'imigrantes': brasil.values.tolist()} #nomenando as colunas listando-as
dados_brasil = spd.DataFrame(brasil_dic)

# %%
#tolist() = usado para criar uma lista

# %%
dados_brasil #data frame formado
# Out:
#      ano  imigrantes
# 0   1980         211
# 1   1981         220
# 2   1982         192
# 3   1983         139
# 4   1984         145
# 5   1985         130
# 6   1986         205
# 7   1987         244
# 8   1988         394
# 9   1989         650
# 10  1990         650
# 11  1991         877
# 12  1992        1066
# 13  1993         866
# 14  1994         566
# 15  1995         572
# 16  1996         586
# 17  1997         591
# 18  1998         531
# 19  1999         626
# 20  2000         845
# 21  2001         847
# 22  2002         745
# 23  2003         839
# 24  2004         917
# 25  2005         969
# 26  2006        1181
# 27  2007        1746
# 28  2008        2138
# 29  2009        2509
# 30  2010        2598
# 31  2011        1508
# 32  2012        1642
# 33  2013        1714

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes']) #(x,y)

# %%
#melhorando a visualização do gráfico

# %%
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes']) #(x,y)
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.show() #código para apenas mostrar o grafico . tudo que tiver abaixo do show não será executado.

# %%
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes']) #(x,y)
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.yticks([500, 1000, 1500, 2000, 2500, 3000])
plt.xlabel('Ano')
plt.ylabel('Imigrantes')
plt.title('Imigrantes do Brasil para o canadá')
plt.show()

# %%
plt.figure(figsize=(8,4)) #o primeiro é a largura e o segundo é a altura
plt.plot(dados_brasil['ano'], dados_brasil['imigrantes']) #(x,y)
plt.xticks(['1980','1985','1990','1995','2000','2005','2010'])
plt.yticks([500, 1000, 1500, 2000, 2500, 3000])
plt.xlabel('Ano')
plt.ylabel('Imigrantes')
plt.title('Imigrantes do Brasil para o canadá')
plt.show()

# %%
fig,ax = plt.subplots(figsize= (8,4) ) #fig permite que uma figura seja criada e ax cria o eixo da fogura
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig,ax = plt.subplots(figsize= (8,4) ) #fig permite que uma figura seja criada e ax cria o eixo da fogura
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'])
ax.set_xticks(['1980','1985','1990','1995','2000','2005','2010'])
ax.set_xlabel('Ano')
ax.set_title('Imigrantes do Brasil para o canadá\n 1980 á 2013')
ax.set_ylabel('Imigrantes')
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #colocando a frequencia de 5 em 5 anos
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# xaxis: Isso acessa as propriedades do eixo X (o eixo horizontal) da sua área de plotagem (ax).
#
# set_major_locator(): Este é um método usado para definir como as principais marcas de seleção (ticks) serão posicionadas no eixo. As "major ticks" são as marcas maiores e mais visíveis que geralmente vêm com um rótulo de valor.
#
# plt.MultipleLocator(5): Aqui, você está criando um objeto MultipleLocator. Ele faz parte do módulo ticker do Matplotlib (muitas vezes acessado diretamente via plt se matplotlib.pyplot foi importado como plt). Ao passar o número 5 para ele, você está dizendo ao Matplotlib para colocar as marcas de seleção principais do eixo X a cada múltiplo de 5. Ou seja, as marcas aparecerão em 0, 5, 10, 15, e assim por diante.

# %%
fig,axs = plt.subplots(1,2, figsize=(15,5)) #a função permite quando graficos vamos colocar na figura
#primeiro grafico
axs[0].plot(dados_brasil['ano'], dados_brasil['imigrantes'])
axs[0].set_title('Imigração do brasil para o canadá\n 1980 á 2013')
axs[0].set_xlabel('Ano')
axs[0].set_ylabel('Imigrantes')
axs[0].xaxis.set_major_locator(plt.MultipleLocator(5)) #colocando a frequencia de 5 em 5 anois no eixo x
axs[0].grid()

#segundo grafico
axs[1].boxplot(dados_brasil['imigrantes'])
axs[1].set_title('Imigração do brasil para o canadá\n 1980 á 2013')
axs[1].set_xlabel('Brasil')
axs[1].set_ylabel('Imigrantes')
axs[1].grid() #para colocar as linhas no grafico
plt.show() #ou plot.show

# %% [markdown]
# **Linha Central Laranja (dentro da caixa): Mediana**
#
# Esta linha representa a mediana dos dados de imigração. A mediana é o valor que divide o conjunto de dados ao meio, ou seja, 50% dos anos tiveram um número de imigrantes abaixo desse valor e 50% tiveram um número acima.
#
# Neste gráfico, a mediana está em torno de 700-750 imigrantes. Isso significa que, na metade dos anos entre 1980 e 2013, o número de imigrantes do Brasil para o Canadá foi igual ou inferior a esse valor, e na outra metade, foi igual ou superior.
#
# **A Caixa (Box): Intervalo Interquartil (IQR)**
#
# A caixa em si (a parte retangular) representa o Intervalo Interquartil (IQR), que vai do primeiro quartil (Q1) ao terceiro quartil (Q3).
#
# Borda Inferior da Caixa (Q1): É o 25º percentil. Significa que 25% dos anos tiveram um número de imigrantes abaixo ou igual a este valor. Neste gráfico, Q1 está aproximadamente em 400-450 imigrantes.
#
# Borda Superior da Caixa (Q3): É o 75º percentil. Significa que 75% dos anos tiveram um número de imigrantes abaixo ou igual a este valor (ou 25% tiveram um número acima). Neste gráfico, Q3 está aproximadamente em 1000-1050 imigrantes.
#
# A largura da caixa (Q3 - Q1) nos dá uma ideia da dispersão dos 50% centrais dos dados. Uma caixa mais estreita indica que os dados estão mais agrupados; uma caixa mais larga indica maior variabilidade.
#
# **As "Hastess" (Whiskers): Intervalo Típico dos Dados**
#
# As linhas verticais que se estendem para cima e para baixo da caixa são chamadas de "whiskers" (bigodes ou hastes). Elas geralmente se estendem até o menor e o maior valor dentro de 1.5 vezes o IQR a partir das bordas da caixa (Q1 e Q3).
#
# A extremidade inferior da haste mostra o valor mínimo de imigração que não é considerado um valor atípico. Parece estar em torno de 150-200 imigrantes.
#
# A extremidade superior da haste mostra o valor máximo de imigração que não é considerado um valor atípico. Parece estar por volta de 1700-1750 imigrantes.
#
# Essas hastes indicam o intervalo onde a maioria dos dados "normais" ou "esperados" está concentrada.
#
# **Os Pontos (Círculos): Outliers (Valores Atípicos)**
#
# Os pontos individuais acima ou abaixo das hastes são os outliers (valores atípicos ou anômalos). São os anos em que o número de imigrantes foi significativamente maior (ou menor, se houvesse pontos abaixo da haste inferior) do que o padrão geral observado na maioria dos anos.
#
# Neste gráfico, vemos dois outliers na parte superior, acima da haste superior, um por volta de 2150-2200 e outro em torno de 2500-2550 imigrantes. Isso sugere que houve anos específicos (entre 1980 e 2013) em que a imigração do Brasil para o Canadá foi excepcionalmente alta em comparação com o resto do período.

# %%
dados_brasil.describe()
# Out:
#         imigrantes
# count    34.000000
# mean    872.323529
# std     663.401232
# min     130.000000
# 25%     428.250000
# 50%     697.500000
# 75%    1041.750000
# max    2598.000000

# %% [markdown]
# fig, axs = plt.subplots(1, 2): Cria uma figura com 1 linha e 2 colunas de subplots. axs será um array unidimensional com dois objetos de eixo: axs[0] e axs[1].

# %%
# Podemos começar analisando os 4 maiores países da América do Sul: Brasil, Colômbia, Argentina e Peru.
# Nosso objetivo é comparar as tendências em uma única figura, utilizando subplots

# %%
fig,axs = plt.subplots(2,2, figsize=(10,6))
fig.subplots_adjust(hspace = 0.5, wspace=0.5) #dando espaçamento entre os graficos
fig.suptitle('Imigração 4 maiores países da América do Sul\n 1980 á 2013')

#0,0 corresponde na posição 1

axs[0,0].plot(df.loc['Brazil', anos])
axs[0,0].set_title('Brasil')
axs[0,0].set_xlabel('Ano')
axs[0,0].set_ylabel('Imigrantes')
axs[0,0].grid()
# axs[0,0].xaxis.set_major_locator(plt.MultipleLocator(5))

#0,1 corresponde na posição 2
axs[0,1].plot(df.loc['Colombia', anos])
axs[0,1].set_title('Colômbia')
axs[0,1].set_xlabel('Ano')
axs[0,1].set_ylabel('Imigrantes')
axs[0,1].grid()
# axs[0,1].xaxis.set_major_locator(plt.MultipleLocator(5))

#1,0 corresponde na posição 3
axs[1,0].plot(df.loc['Argentina', anos])
axs[1,0].set_xlabel('Ano')
axs[1,0].set_ylabel('Imigrantes')
axs[1,0].set_title('Argentina')
axs[1,0].grid()
# axs[1,0].xaxis.set_major_locator(plt.MultipleLocator(5))


#1,1 corresponde na posição 4
axs[1,1].plot(df.loc['Peru', anos])
axs[1,1].set_xlabel('Ano')
axs[1,1].set_ylabel('Imigrantes')
axs[1,1].set_title('Peru')
axs[1,1].grid()
# axs[1,1].xaxis.set_major_locator(plt.MultipleLocator(5))

for ax in axs.flat: #vai criar um loop que vai percorrer todas as celulas
  ax.xaxis.set_major_locator(plt.MultipleLocator(5))

ymim= 0
ymax = 7000

for ax in axs.ravel():
  ax.set_ylim(ymim,ymax) #ylim de linha e xlim de linha

plt.show()

# %% [markdown]
# O loc em pandas é usado para selecionar dados de um DataFrame ou Series com base em rótulos (labels) de linhas e colunas. Ele é puramente baseado em rótulos e aceita.
#
# O método .ravel() é um método de arrays NumPy que "achata" o array, transformando-o em uma única dimensão.
# No exemplo acima, se axs é um array (2, 2), axs.ravel() o transformaria em um array unidimensional:
#
# [ax1, ax2, ax3, ax4]

# %% [markdown]
# **Detalhes que podemos acrescentar no grafico.**

# %%
fig,ax = plt.subplots(figsize= (8,4) ) #fig permite que uma figura seja criada e ax cria o eixo da fogura
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, marker='o') #lw é usado para aumentar a espessura da linha. E o o é usado para delimitar os pontos da linha.
ax.set_xticks(['1980','1985','1990','1995','2000','2005','2010'])
ax.set_xlabel('Ano',fontsize=14)
ax.set_title('Imigrantes do Brasil para o canadá\n 1980 á 2013 ', fontsize=18,loc='left')#frontsize é usado para definir o tamanha das fontes
ax.set_ylabel('Número de Imigrante',fontsize=14)#frontsize é usado para definir o tamanha das fontes
ax.xaxis.set_tick_params(labelsize=12)#labelsize é usado para definir o tamanha das fontes no eixo x
ax.yaxis.set_tick_params(labelsize=12)#labelsize é usado para definir o tamanha das fontes no eixo y
ax.xaxis.set_major_locator(plt.MultipleLocator(5)) #colocando a frequencia de 5 em 5 anos
plt.grid(linestyle= '--') #deixando o grid mais suave
plt.show()

# %%
fig,ax = plt.subplots(figsize= (8,4) ) #fig permite que uma figura seja criada e ax cria o eixo da fogura
ax.plot(dados_brasil['ano'], dados_brasil['imigrantes'], lw=3, color= 'g')
ax.set_xticks(['1980','1985','1990','1995','2000','2005','2010'])
ax.set_xlabel('Ano',fontsize=14)
ax.set_title('Imigrantes do Brasil para o canadá\n 1980 á 2013 ', fontsize=18,loc='left')#frontsize é usado para definir o tamanha das fontes
ax.set_ylabel('Número de Imigrante',fontsize=14)#frontsize é usado para definir o tamanha das fontes
ax.xaxis.set_tick_params(labelsize=12)#labelsize é usado para definir o tamanha das fontes no eixo x
ax.yaxis.set_tick_params(labelsize=12)#labelsize é usado para definir o tamanha das fontes no eixo y

ax.spines['top'].set_visible(False) #para tirar a linha de cima
ax.spines['right'].set_visible(False) #para tirar a linha da direita

plt.show()

# %%
df.head()
# Out:
#                Continent           Region             DevName  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  2005  2006  2007  2008  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  3436  3009  2652  2111
# Albania            0     0     0     0     1  ...  1223   856   702   560
# Algeria           71    69    63    44    69  ...  3626  4807  3623  4005
# American Samoa     0     0     0     0     0  ...     0     1     0     0
# Andorra            0     0     0     0     2  ...     0     1     1     0
#
# ...

# %%
america_sul= df.query('Region =="South America"')

# %%
america_sul
# Out:
#                                                           Continent  \
# Country
# Argentina                           Latin America and the Caribbean
# Bolivia (Plurinational State of)    Latin America and the Caribbean
# Brazil                              Latin America and the Caribbean
# Chile                               Latin America and the Caribbean
# Colombia                            Latin America and the Caribbean
# Ecuador                             Latin America and the Caribbean
# Guyana                              Latin America and the Caribbean
# Paraguay                            Latin America and the Caribbean
# Peru                                Latin America and the Caribbean
# Suriname                            Latin America and the Caribbean
# Uruguay                             Latin America and the Caribbean
# Venezuela (Bolivarian Republic of)  Latin America and the Caribbean
#
# ...

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown'
, 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize=(12,5)) #criando um subplotde barras
ax.bar(america_sul.index, america_sul['Total'], color = cores )
ax.set_title('Imigrantes da A mérica do Sul para o canadá\n 1980 á 2013', fontsize= 18, loc ='left')
ax.set_xlabel('País', fontsize=14)
ax.set_ylabel('Número de Imigrante', fontsize=14)
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown'
, 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize=(12,5)) #criando um subplotde barras
ax.barh(america_sul.index, america_sul['Total'], color = cores )  #ao colocar o H criamos um grafico de barras na horizontal
ax.set_title('Imigrantes da A mérica do Sul para o canadá\n 1980 á 2013', fontsize= 18, loc ='left')
ax.set_xlabel('Número de Imigrante', fontsize=14)
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# %%
america_sul_sorted=america_sul.sort_values('Total', ascending= True) #ordennação do maior para o menor

# %%
cores = ['royalblue', 'orange', 'forestgreen', 'orchid', 'purple', 'brown'
, 'slateblue', 'gray', 'olive', 'navy', 'teal', 'tomato']

fig, ax = plt.subplots(figsize=(12,5)) #criando um subplotde barras
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color = cores )  #ao colocar o H criamos um grafico de barras na horizontal
ax.set_title('Imigrantes da A mérica do Sul para o canadá\n 1980 á 2013', fontsize= 18, loc ='left')
ax.set_xlabel('Número de Imigrante', fontsize=14)
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

# %%
cores = [] #isso nos permite
for pais in america_sul_sorted.index:
  if pais == 'Brazil':
    cores.append('green')
  else:
    cores.append('silver')

fig, ax = plt.subplots(figsize=(12,5)) #criando um subplotde barras
ax.barh(america_sul_sorted.index, america_sul_sorted['Total'], color = cores )  #ao colocar o H criamos um grafico de barras na horizontal
ax.set_title('América do Sul: Brasil foi o 4 pais com mais imigrantes\n para o canadá no periodo de 1980 à 2013 ', fontsize= 18, loc ='left')
ax.set_xlabel('Número de Imigrante', fontsize=14)
ax.set_ylabel('')
ax.xaxis.set_tick_params(labelsize=12)
ax.yaxis.set_tick_params(labelsize=12)

for i, v in enumerate(america_sul_sorted['Total']): #para colocar textos juntamente as barras
  ax.text(v + 20, i, str(v), color='black', fontsize=10, ha= 'left', va='center') #ha determina a posição do texto, fontsize o tamanho, va determina o alinhamento vertical do texto

ax.set_frame_on(False) #para tirar a borda do grafico
ax.get_xaxis().set_visible(False) #para tirar o eixo x
ax.tick_params(axis='both', which = 'both', length=0) #para tirar os ticks(marcadores) do eixo y. both= tirar de todos

fig.savefig('América do Sul: Brasil foi o 4 pais com mais imigrantes\n para o canadá no periodo de 1980 à 2013.png', transparent= False, dpi=300, bbox_inches='tight') #comando para salvar a imagem
plt.show()

# %%
print(fig.canvas.get_supported_filetypes()) #comando para salavr o grafico
# Out:
# {'eps': 'Encapsulated Postscript', 'jpg': 'Joint Photographic Experts Group', 'jpeg': 'Joint Photographic Experts Group', 'pdf': 'Portable Document Format', 'pgf': 'PGF code for LaTeX', 'png': 'Portable Network Graphics', 'ps': 'Postscript', 'raw': 'Raw RGBA bitmap', 'rgba': 'Raw RGBA bitmap', 'svg': 'Scalable Vector Graphics', 'svgz': 'Scalable Vector Graphics', 'tif': 'Tagged Image File Format', 'tiff': 'Tagged Image File Format', 'webp': 'WebP Image Format'}

# %%
import seaborn as sns

# %%
sns.set_theme()

# %% [markdown]
# ascending=False: Este é o argumento crucial. Ele indica que a ordenação deve ser feita de forma decrescente. Ou seja, o maior valor de 'Total' aparecerá primeiro, seguido pelo segundo maior, e assim por diante, até o menor.

# %%
#vamos fazer um top 10 dos paises mais imigrantes para o canadá
top_10= df.sort_values('Total', ascending= False).head(10)

# %%
top_10
# Out:
#                                                            Continent  \
# Country
# India                                                           Asia
# China                                                           Asia
# United Kingdom of Great Britain and Northern Ir...            Europe
# Philippines                                                     Asia
# Pakistan                                                        Asia
# United States of America                            Northern America
# Iran (Islamic Republic of)                                      Asia
# Sri Lanka                                                       Asia
# Republic of Korea                                               Asia
# Poland                                                        Europe
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# ...

# %%
sns.barplot(data= top_10, x= top_10.index, y= 'Total') #criando um grafico de barras
# Out:
# <Axes: xlabel='Country', ylabel='Total'>

# %%
sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h', palette= 'cubehelix') #criando um grafico de barras na horizontal
# Out:
# /tmp/ipython-input-48-2191646811.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h', palette= 'cubehelix') #criando um grafico de barras na horizontal
# <Axes: xlabel='Total', ylabel='Country'>

# %%
ax= sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= 'cubehelix')

ax.set(title='Paises com maior imigração para o canadá\n 1980 à 2013',
       xlabel= 'Número de Imigrantes',
       ylabel= '')

plt.show()
# Out:
# /tmp/ipython-input-49-3072799763.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax= sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= 'cubehelix')

# %%
ax= sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= 'cubehelix')

ax.set_title('Paises com maior imigração para o canadá\n 1980 à 2013',loc= 'left')
ax.set(xlabel= 'Número de Imigrantes',
       ylabel= '')

plt.show()
# Out:
# /tmp/ipython-input-50-1133397028.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax= sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= 'cubehelix')

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax= sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= 'cubehelix')

ax.set_title('Paises com maior imigração para o canadá\n 1980 à 2013',loc= 'left', fontsize =16)
ax.set_xlabel('Número de Imigrantes', fontsize =14)
ax.set_ylabel('')
plt.show()
# Out:
# /tmp/ipython-input-51-1871920482.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax= sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= 'cubehelix')

# %%
def gerar_grafico_paleta(palette):
  fig, ax = plt.subplots(figsize=(8,4))
  ax = sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= palette)
  ax.set_title('Paises com maior imigração para o canadá\n 1980 à 2013',loc= 'left', fontsize =16)
  ax.set_xlabel('Número de Imigrantes', fontsize =14)
  ax.set_ylabel('')
  plt.show()

# %%
gerar_grafico_paleta('Blues')
# Out:
# /tmp/ipython-input-54-1194901851.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= palette)

# %%
gerar_grafico_paleta('Blues_r')#usando o reverso
# Out:
# /tmp/ipython-input-57-1755059537.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= palette)

# %%
gerar_grafico_paleta('rocket')
# Out:
# /tmp/ipython-input-57-1755059537.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= palette)

# %%
gerar_grafico_paleta('coolwarm')
# Out:
# /tmp/ipython-input-57-1755059537.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= palette)

# %%
gerar_grafico_paleta('tab10')
# Out:
# /tmp/ipython-input-57-1755059537.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= palette)

# %%
sns.set_theme(style='dark') #mudar o fundo
gerar_grafico_paleta('tab10')
# Out:
# /tmp/ipython-input-57-1755059537.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= palette)

# %%
sns.set_theme(style='whitegrid') #mudar o fundo
gerar_grafico_paleta('tab10')
# Out:
# /tmp/ipython-input-57-1755059537.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= palette)

# %%
sns.set_theme(style='white') #mudar o fundo
gerar_grafico_paleta('tab10')
# Out:
# /tmp/ipython-input-57-1755059537.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= palette)

# %%
sns.set_theme(style='ticks') #mudar o fundo
gerar_grafico_paleta('tab10')
# Out:
# /tmp/ipython-input-57-1755059537.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= palette)

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax= sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= 'tab10')
ax.set_title('Paises com maior imigração para o canadá\n 1980 à 2013',loc= 'left', fontsize =16)
ax.set_xlabel('Número de Imigrantes', fontsize =14)
ax.set_ylabel('')
sns.despine() #para tirar a borda do grafico

plt.show()
# Out:
# /tmp/ipython-input-77-1592300661.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax= sns.barplot(data= top_10, x= 'Total', y= top_10.index, orient='h',palette= 'tab10')
