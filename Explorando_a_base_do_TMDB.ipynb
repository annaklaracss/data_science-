# %% [markdown]
# <a href="https://colab.research.google.com/github/annaklaracss/data_science-/blob/main/Explorando_a_base_do_TMDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
tmdb = pd.read_csv('https://raw.githubusercontent.com/annaklaracss/data_science-/refs/heads/main/tmdb_5000_movies.csv?token=GHSAT0AAAAAADFNH5J6S3HA3L5CSKYAZCAO2CZTWGQ')
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.displot(tmdb['revenue'])
plt.title('distribuição de receitas dos filmes')
plt.show()

# %%
# prompt: grafico de distribioção do orçamento dos filme (budget)

import matplotlib.pyplot as plt
sns.displot(tmdb['budget'])
plt.title('distribuição do orçamento dos filmes')
plt.show()

# %%
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
com_faturamento = tmdb.query('revenue > 0')
com_faturamento.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  3.376000e+03    3376.000000  3376.000000  3.376000e+03  3376.000000
# mean   3.888424e+07   45518.799171    28.260492  1.170314e+08   110.382109
# std    4.420490e+07   74725.406344    35.622362  1.834831e+08    21.116082
# min    0.000000e+00       5.000000     0.019984  5.000000e+00     0.000000
# 25%    8.500000e+06    5538.250000     9.957286  1.535290e+07    96.000000
# 50%    2.500000e+07   11581.500000    19.755221  5.175184e+07   106.000000
# 75%    5.200000e+07   47370.750000    36.425937  1.401651e+08   121.000000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   3376.000000   3376.000000
# mean       6.308738    944.422690
# std        0.882279   1392.846418
# min        0.000000      0.000000
# 25%        5.800000    160.750000
# 50%        6.300000    440.500000
# 75%        6.900000   1091.250000
# ...

# %%
com_faturamento = tmdb.query('revenue > 0')
sns.displot(com_faturamento['revenue'])

# %% [markdown]
# Variáveis são características, atributos ou quantidades de uma amostra ou população que podem ser mensuradas, contadas ou categorizadas. Elas são fundamentais para descrever e entender os fenômenos em estudo.

# %% [markdown]
# **Variáveis Qualitativas:**
# representam características que não podem ser medidas numericamente, mas podem ser categorizadas, ou seja, representam uma classificação
#
# -Nominal; classifica os elementos em classes ou categorias em relação ao tipo do dado representado. Ela não possui uma relação de grandeza ou ordem dos dados
#
# Exemplos: Nome de produtos, departamentos, métodos de pagamento ou variáveis geográficas, como, cidade, estado e região.
#
# -Ordinal; classifica os elementos em classes ou categorias, porém existe uma ordem natural ou hierárquica entre as categorias.
#
# Exemplos: grau de escolaridade (ensino infantil, ensino fundamental, ensino médio), nível de satisfação do cliente (insatisfeito, neutro e satisfeito) e nível socioeconômico.
#
# **Variáveis Quantitativas**
#
# Representam medidas numéricas ou quantidades observáveis que podem ser expressas em números. Elas são resultantes de contagens (conjunto finito de valores) ou mensurações (conjunto infinito de valores). Estas variáveis podem ser discretas ou contínuas.
#
# -Discreta; Uma variável quantitativa discreta é aquela que apresenta valores que podem ser contados e geralmente inteiros.
#
# Exemplos: quantidade de produto vendido, número de cômodos em uma casa e idade.
#
# -Contínua;
# Uma variável quantitativa contínua é aquela que apresenta valores que podem assumir qualquer valor dentro de um intervalo específico e geralmente são expressos como números reais.
#
# Exemplos: peso de um produto, altura de uma pessoa, tempo e temperatura de um experimento.

# %%
tmdb['original_language'].value_counts() #.value_counts(), obtivemos a contagem de cada idioma em uma única série.
# Out:
# original_language
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ko      11
# ru      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# id       2
# cs       2
# ta       2
# ro       2
# ar       2
# te       1
# hu       1
# xx       1
# af       1
# is       1
# tr       1
# vi       1
# pl       1
# nb       1
# ky       1
# no       1
# sl       1
# ps       1
# el       1
# Name: count, dtype: int64

# %%
#dessa vez temos letras e numeros misturados (variaveis qualitativas e quantitativas)

# %%
tmdb['original_language'].value_counts().to_frame() #para transformar em um data frame
# Out:
#                    count
# original_language
# en                  4505
# fr                    70
# es                    32
# zh                    27
# de                    27
# hi                    19
# ja                    16
# it                    14
# cn                    12
# ko                    11
# ru                    11
# pt                     9
# da                     7
# sv                     5
# nl                     4
# fa                     4
# th                     3
# he                     3
# id                     2
# cs                     2
# ta                     2
# ro                     2
# ar                     2
# te                     1
# hu                     1
# xx                     1
# af                     1
# is                     1
# tr                     1
# vi                     1
# pl                     1
# nb                     1
# ky                     1
# no                     1
# sl                     1
# ...

# %%
contagem_de_lingua = tmdb['original_language'].value_counts().to_frame().reset_index() #criou um inidice novo
contagem_de_lingua.columns = ['original_language','total']
contagem_de_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
contagem_de_lingua.plot()
# Out:
# <Axes: >

# %%
sns.barplot(data = contagem_de_lingua, x = 'original_language', y = 'total') #grafico de barra para a melhor visualização (em barra)
# Out:
# <Axes: xlabel='original_language', ylabel='total'>

# %%
sns.countplot(data = tmdb, x = 'original_language')
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
contagem_de_lingua.plot(kind="pie", y="total")
# Out:
# <Axes: ylabel='total'>

# %%
contagem_de_lingua.plot(kind="pie", y="total", labels=contagem_de_lingua["original_language"])
# Out:
# <Axes: ylabel='total'>

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_de_ingles = total_por_lingua.loc["en"]
total_de_ingles
# Out:
# np.int64(4505)

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_de_ingles = total_por_lingua.loc["en"]
total_de_ingles
# Out:
# np.int64(4505)

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc["en"]
total_do_resto = total_geral - total_de_ingles

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc["en"]
total_do_resto = total_geral - total_de_ingles
print(total_geral, total_de_ingles, total_do_resto)
# Out:
# 4803 4505 298

# %%
#criação do data frame e de uma biblioteca
dados = {
  "lingua" : ["ingles", "outros"],
  "total" : [total_de_ingles, total_do_resto]
}
dados = pd.DataFrame(dados)
dados
# Out:
#    lingua  total
# 0  ingles   4505
# 1  outros    298

# %%
sns.barplot(data=dados, x="lingua", y="total") #Agora, queremos usar o Seaborn (sns) para fazer um gráfico de barras (barplot()).
# Out:
# <Axes: xlabel='lingua', ylabel='total'>

# %%
#Agora, poderíamos pegar esses dados e transformá-los em um gráfico de pizza, definindo os rótulos de y como total e os labels como lingua.
dados.plot(kind="pie", y="total", labels=dados["lingua"])
# Out:
# <Axes: ylabel='total'>

# %%
tmdb.query("original_language != 'en'")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
total_de_filmes_por_lingua = tmdb.query("original_language != 'en'")['original_language'].value_counts()
total_de_filmes_por_lingua.head()
# Out:
# original_language
# fr    70
# es    32
# zh    27
# de    27
# hi    19
# Name: count, dtype: int64

# %%
sns.countplot(data=tmdb.query("original_language != 'en'"),
              x="original_language")
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
sns.countplot(data=tmdb.query("original_language != 'en'"),
              order= total_de_filmes_por_lingua.index,#reorganizou por ordem. Decrescente!!
              hue="original_language",#colocando as cores das barras
              x="original_language")
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
sns.color_palette('mako') #palheta de cores mako
# Out:
# [(0.18195582, 0.11955283, 0.23136943),
#  (0.25307401, 0.23772973, 0.48316271),
#  (0.21607792, 0.39736958, 0.61948028),
#  (0.20344718, 0.56074869, 0.65649508),
#  (0.25187832, 0.71827158, 0.67872193),
#  (0.54578602, 0.8544913, 0.69848331)]

# %%
sns.countplot(data=tmdb.query("original_language != 'en'"),
              order= total_de_filmes_por_lingua.index,#reorganizou por ordem. Decrescente!!
              palette="mako",#colocando as cores das barras
              hue="original_language",#colocando as cores das barras
              x="original_language")
# Out:
# <Axes: xlabel='original_language', ylabel='count'>

# %%
sns.countplot(data=tmdb.query("original_language != 'en'"),
              order= total_de_filmes_por_lingua.index,#reorganizou por ordem. Decrescente!!
              palette="mako",#colocando as cores das barras
              hue="original_language",#colocando as cores das barras
              hue_order= total_de_filmes_por_lingua.index, #deixando as cores em ordem no grafico
              x="original_language")
plt.title("Quantidade de filmes por lingua excerto em inglês")
# Out:
# Text(0.5, 1.0, 'Quantidade de filmes por lingua excerto em inglês')

# %% [markdown]
# repare que o value_counts possui vários parâmetros, um deles o normalize. Vamos testá-lo. Voltamos ao Google Colab e nos parênteses de value_count() passamos normalize=True.

# %%
tmdb.query("original_language != 'en'")["original_language"].value_counts(normalize=True)
# Out:
# original_language
# fr    0.234899
# es    0.107383
# zh    0.090604
# de    0.090604
# hi    0.063758
# ja    0.053691
# it    0.046980
# cn    0.040268
# ko    0.036913
# ru    0.036913
# pt    0.030201
# da    0.023490
# sv    0.016779
# nl    0.013423
# fa    0.013423
# th    0.010067
# he    0.010067
# id    0.006711
# cs    0.006711
# ta    0.006711
# ro    0.006711
# ar    0.006711
# te    0.003356
# hu    0.003356
# xx    0.003356
# af    0.003356
# is    0.003356
# tr    0.003356
# vi    0.003356
# pl    0.003356
# nb    0.003356
# ky    0.003356
# no    0.003356
# sl    0.003356
# ps    0.003356
# el    0.003356
# Name: proportion, dtype: float64

# %%
sns.countplot(data=tmdb.query("original_language != 'en'"),
              order= total_de_filmes_por_lingua.index,#reorganizou por ordem. Decrescente!!
              palette="mako",#colocando as cores das barras
              hue="original_language",#colocando as cores das barras
              hue_order= total_de_filmes_por_lingua.index,#deixando as cores em ordem no grafico
              stat= 'percent', #dando o grafico em porcentagem
              x="original_language")
plt.title("Quantidade de filmes por lingua excerto em inglês")
# Out:
# Text(0.5, 1.0, 'Quantidade de filmes por lingua excerto em inglês')

# %%
plt.figure(figsize=(16,8)) #tamanho da figura

sns.countplot(data=tmdb.query("original_language != 'en'"),
              order= total_de_filmes_por_lingua.index,#reorganizou por ordem. Decrescente!!
              palette="mako",#colocando as cores das barras
              hue="original_language",#colocando as cores das barras
              hue_order= total_de_filmes_por_lingua.index,#deixando as cores em ordem no grafico
              stat= 'percent', #dando o grafico em porcentagem
              x="original_language")
plt.title("Quantidade de filmes por lingua excerto em inglês")
# Out:
# Text(0.5, 1.0, 'Quantidade de filmes por lingua excerto em inglês')
